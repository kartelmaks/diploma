# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import matplotlib

from scipy.signal import savgol_filter
from scipy.cluster.hierarchy import dendrogram

from sklearn.cluster import AgglomerativeClustering
from sklearn.decomposition import PCA as pca
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans

plt.style.use('ggplot')

# %%
x1 = 291.4
x2 = 3823.2

X1 = pd.read_csv('D:\\unik\\nauchka\data\\Cells_aging_for_Kartel_msc\\ethanol_cell_8x8.csv')
X2 = pd.read_csv('D:\\unik\\nauchka\data\\Cells_aging_for_Kartel_msc\\formalin_cell_8x8.csv')
X3 = pd.read_csv('D:\\unik\\nauchka\data\\Cells_aging_for_Kartel_msc\\methanol_cell_8x8.csv')
X4 = pd.read_csv('D:\\unik\\nauchka\data\\Cells_aging_for_Kartel_msc\\pure_cell_8x8.csv')

X1 = X1.loc[:,str(x1):str(x2)]
X2 = X2.loc[:,str(x1):str(x2)]
X3 = X3.loc[:,str(x1):str(x2)]
X4 = X4.loc[:,str(x1):str(x2)]

# %%
print(X1.shape)
print(X2.shape)
# Out:
# (64, 1340)
# (48, 1340)

# %%
X = X1.append(X3)
X = X.append(X4)
X = X.append(X2)

# %% [markdown]
# Перевірка осі Х

# %%
Y = pd.read_csv('D:\\unik\\nauchka\data\\Cells_aging_for_Kartel_msc\\ethanol_cell_8x8.csv', header=None)
Y.columns  = list(Y.iloc[0, :])
y1 = Y.loc[0,x1:x2]

# %%
y1.shape
# Out:
# (1340,)

# %%
X_np = np.asarray(X)

# %%
X_np.shape
# Out:
# (240, 1340)

# %%
crit = []

for k in range(2, 20):
    kmeans = KMeans(n_clusters=k, random_state=1)
    kmeans.fit(X)
    
    crit.append(kmeans.inertia_)

plt.plot(range(2,20), crit)

# %%
nspec, nw = X_np.shape

# %%
n_clusters = 8

kmeans = KMeans(n_clusters=n_clusters, init='k-means++')

kmeans.fit(X)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=8, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
X['labels'] = kmeans.labels_
labels_mean = X.groupby(['labels']).mean()

# %%
labels1 = kmeans.labels_[0:64]
labels2 = kmeans.labels_[192:240]
labels3 = kmeans.labels_[64:128]
labels4 = kmeans.labels_[128:192]

# %%
labels_arr = {'ethanol':labels1, 'formalin':labels2, 'methanol':labels3, 'pure':labels4}

# %%
y1.index = y1

# %%
def dich(n, hight, width, material_n, labels_arr):
    fig, axes = plt.subplots(nrows=material_n+1, ncols=n_clusters, figsize=(30,10))
        
    for i in range(n_clusters):
        axes[0,i].set(title = "Cluster " + str(i))
        axes[0,i].plot(y1, labels_mean.loc[i])
      
    arr = np.zeros([4,8])
    
    k=1
    for key in labels_arr:
            
        for i in range(n_clusters):
            cl = np.zeros(n)
                
            for j in range(len(labels_arr[key])):
                if i == labels_arr[key][j]:
                    cl[j] = 1
                    arr[k-1,i] += 1
                #print(arr[k-1, i])
                R = np.reshape(cl, (hight, width))
                axes[k,i].imshow(R)
            axes[k,0].set_ylabel(key)
        k+=1
    return arr     
            
arr = dich(64, 8, 8, 4, labels_arr)

# %%
arr
# Out:
# array([[ 0., 34.,  0.,  0., 14., 16.,  0.,  0.],
#        [14.,  0.,  0.,  2., 19.,  0.,  0., 13.],
#        [ 0.,  0., 34.,  0.,  3.,  0., 27.,  0.],
#        [18.,  0.,  0., 13.,  5.,  0.,  0., 28.]])

# %%
arr_sum = [0,0,0,0]
arr_div = [0,0,0,0]

for j in range(4):
    for i in range(8):
        arr_sum[j] += arr[j,i]

for r in range(4):
    arr_sum[r] = arr_sum[r]/arr_sum[3]

for j in range(4):
    for i in range(8):
        if (arr[3,i] != 0):
            if (arr[j,i]/arr[3,i] < 1):
                arr_div[j] += arr[j,i]/arr[3,i]
            else: arr_div[j] += arr[3,i]/arr[j,i]

for r in range(4):
    arr_div[r] = arr_div[r]/arr_sum[r]
    
for r in range(4):
    arr_div[r] = arr_div[r]/arr_div[3]
    
print(arr_div)
# Out:
# [0.08928571428571429, 0.5530225135488293, 0.15, 1.0]

# %% [raw]
# def plot_all(labels_arr):
#     for i in labels_arr:
#         dich(64, i, 8, 8, )
